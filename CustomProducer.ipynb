# %%
pip install confluent_kafka
# Out:
# Requirement already satisfied: confluent_kafka in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (2.3.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from confluent_kafka import Producer
import time

# %%
bootstrap_servers = '127.0.0.1:9092'

# %%
def delivery_report(err, msg):
    if err is not None:
        print(f'Message delivery failed: {err}')
    else:
        print(f'Message delivered to {msg.topic()} [{msg.partition()}]')

# %%
producer = Producer({'bootstrap.servers': bootstrap_servers})

# %%
topic = 'first_topic'

# %%
try:
    while True:
        producer.produce(topic, key=None, value='Hello Kafka from Conduktor!', callback=delivery_report)
        producer.flush()  
        time.sleep(1)  
except KeyboardInterrupt:
    pass
finally:
 
    producer.flush()
# Out:
# Message delivered to first_topic [0]
# Message delivered to first_topic [2]
# Message delivered to first_topic [2]
# Message delivered to first_topic [0]
# Message delivered to first_topic [1]
# Message delivered to first_topic [1]
# Message delivered to first_topic [1]
# Message delivered to first_topic [2]
# Message delivered to first_topic [0]
# Message delivered to first_topic [2]
# Message delivered to first_topic [0]
# Message delivered to first_topic [2]
# Message delivered to first_topic [0]
# Message delivered to first_topic [0]
# Message delivered to first_topic [0]
# Message delivered to first_topic [0]
# Message delivered to first_topic [1]
# Message delivered to first_topic [2]
# Message delivered to first_topic [1]
# Message delivered to first_topic [0]
# Message delivered to first_topic [1]
# Message delivered to first_topic [0]
# Message delivered to first_topic [2]
# Message delivered to first_topic [1]
# Message delivered to first_topic [1]
# Message delivered to first_topic [1]
# Message delivered to first_topic [2]
# Message delivered to first_topic [0]
# Message delivered to first_topic [2]
# Message delivered to first_topic [0]
# Message delivered to first_topic [1]
# Message delivered to first_topic [2]
# Message delivered to first_topic [1]
# Message delivered to first_topic [1]
# Message delivered to first_topic [2]
# Message delivered to first_topic [1]
# Message delivered to first_topic [0]
# Message delivered to first_topic [0]
# Message delivered to first_topic [1]
# Message delivered to first_topic [1]
# Message delivered to first_topic [0]
# Message delivered to first_topic [1]
# Message delivered to first_topic [2]
# %6|1706879316.492|FAIL|rdkafka#producer-4| [thrd:127.0.0.1:9092/bootstrap]: 127.0.0.1:9092/0: Disconnected (after 10332200ms in state UP)
# %6|1706879316.498|FAIL|rdkafka#producer-3| [thrd:127.0.0.1:9092/bootstrap]: 127.0.0.1:9092/0: Disconnected (after 22074629ms in state UP)
# %3|1706879316.600|FAIL|rdkafka#producer-3| [thrd:127.0.0.1:9092/bootstrap]: 127.0.0.1:9092/0: Connect to ipv4#127.0.0.1:9092 failed: Connection refused (after 0ms in state CONNECT)
# %3|1706879316.966|FAIL|rdkafka#producer-4| [thrd:127.0.0.1:9092/bootstrap]: 127.0.0.1:9092/0: Connect to ipv4#127.0.0.1:9092 failed: Connection refused (after 0ms in state CONNECT)
# %3|1706879317.600|FAIL|rdkafka#producer-3| [thrd:127.0.0.1:9092/bootstrap]: 127.0.0.1:9092/0: Connect to ipv4#127.0.0.1:9092 failed: Connection refused (after 0ms in state CONNECT, 1 identical error(s) suppressed)
# %3|1706879317.964|FAIL|rdkafka#producer-4| [thrd:127.0.0.1:9092/bootstrap]: 127.0.0.1:9092/0: Connect to ipv4#127.0.0.1:9092 failed: Connection refused (after 0ms in state CONNECT, 1 identical error(s) suppressed)
